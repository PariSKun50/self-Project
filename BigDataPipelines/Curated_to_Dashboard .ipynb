# %% [markdown]
# ## Objective:
# This is the third notebook in the assignment and deals with:
# - reading data from the curated database
# - answering the questions asked and
# - creating dashboards wherever applicable.

# %% [markdown]
# The databricks public link to this workbook is https://databricks-prod-cloudfront.cloud.databricks.com/public/4027ec902e239c93eaaa8714f173bcfc/1721482899250574/1371319005645532/2654077590604412/latest.html

# %%
# %sql
-- Run the following command to view all the tables present in the staging schema

USE curated;
SHOW TABLES;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>curated</td><td>completed_customer_orders</td><td>false</td></tr><tr><td>curated</td><td>completed_orders_metrics</td><td>false</td></tr><tr><td>curated</td><td>other_orders_metrics</td><td>false</td></tr><tr><td>curated</td><td>refunded_orders_metrics</td><td>false</td></tr><tr><td>curated</td><td>rfm_metrics</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# #### Visualisations, where applicable, have been created using DataBricks in-built option. Please toggle between the table and visualisation options to view the output.

# %% [markdown]
# #### Q1.	Find revenue generated by different categories for the month of 11/2020.
# - To answer this question, we'll consider the *_completed_orders_metrics_* table.

# %%
# %sql

SELECT Category,
       (sum(Revenue)/1000000)::decimal(10,2) as revenue
FROM curated.completed_orders_metrics
where Month_Year = 'Nov-2020'
group by 1
order by 2 desc;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Category</th><th>revenue</th></tr></thead><tbody><tr><td>Mobiles & Tablets</td><td>1.44</td></tr><tr><td>Entertainment</td><td>0.65</td></tr><tr><td>Women's Fashion</td><td>0.17</td></tr><tr><td>Computing</td><td>0.15</td></tr><tr><td>Others</td><td>0.15</td></tr><tr><td>Appliances</td><td>0.14</td></tr><tr><td>Beauty & Grooming</td><td>0.08</td></tr><tr><td>Men's Fashion</td><td>0.08</td></tr><tr><td>Superstore</td><td>0.05</td></tr><tr><td>Home & Living</td><td>0.03</td></tr><tr><td>Kids & Baby</td><td>0.01</td></tr><tr><td>Health & Sports</td><td>0.01</td></tr><tr><td>Soghaat</td><td>0.01</td></tr><tr><td>School & Education</td><td>0.00</td></tr><tr><td>Books</td><td>0.00</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# #### Q2.	Which top 5 categories have a maximum number of refunds in the year 2020?
# - To compute this, we will consider the *_refunded_orders_metrics_* table

# %%
# %sql

select Category,
       sum(TotalOrders) as OrdersRefunded
from refunded_orders_metrics
where Year = 2020
group by 1
order by 2 desc
limit 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Category</th><th>OrdersRefunded</th></tr></thead><tbody><tr><td>Men's Fashion</td><td>2947</td></tr><tr><td>Mobiles & Tablets</td><td>1923</td></tr><tr><td>Women's Fashion</td><td>1318</td></tr><tr><td>Appliances</td><td>938</td></tr><tr><td>Beauty & Grooming</td><td>551</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# #### Q3) Find the total number of orders by each category for each month and year in the dataset?
# - We will consider **all three order tables** i.e, completed, refunded and other orders.
# - The function MONTH(TO_DATE(Month_Year, 'MMM-yyyy')) converts the Month_Year values from 'Jan-2021', 'Feb-2021',..., 'Dec-2021' to 1,2,...12. This helps in arranging the output sequentially.

# %%
# %sql

with all_orders as (
select Category,
       Year,
       MONTH(TO_DATE(Month_Year, 'MMM-yyyy')) AS Month,
       sum(TotalOrders) as TotalOrders
from completed_orders_metrics
Health & Sports</td><td>2020</td><td>12</td><td>826</td></tr><tr><td>Superstore</td><td>2020</td><td>12</td><td>1133</td></tr><tr><td>Others</td><td>2020</td><td>12</td><td>272</td></tr><tr><td>Books</td><td>2020</td><td>12</td><td>91</td></tr><tr><td>School & Education</td><td>2020</td><td>12</td><td>104</td></tr><tr><td>Beauty & Grooming</td><td>2020</td><td>12</td><td>2920</td></tr><tr><td>Entertainment</td><td>2020</td><td>12</td><td>5505</td></tr><tr><td>Women's Fashion</td><td>2020</td><td>12</td><td>4558</td></tr><tr><td>Mobiles & Tablets</td><td>2020</td><td>12</td><td>18543</td></tr><tr><td>Kids & Baby</td><td>2020</td><td>12</td><td>1149</td></tr><tr><td>Women's Fashion</td><td>2021</td><td>1</td><td>1612</td></tr><tr><td>Kids & Baby</td><td>2021</td><td>1</td><td>399</td></tr><tr><td>Superstore</td><td>2021</td><td>1</td><td>429</td></tr><tr><td>Men's Fashion</td><td>2021</td><td>1</td><td>2283</td></tr><tr><td>School & Education</td><td>2021</td><td>1</td><td>33</td></tr><tr><td>Appliances</td><td>2021</td><td>1</td><td>1828</td></tr><tr><td>Soghaat</td><td>2021</td><td>1</td><td>547</td></tr><tr><td>Others</td><td>2021</td><td>1</td><td>92</td></tr><tr><td>Computing</td><td>2021</td><td>1</td><td>456</td></tr><tr><td>Home & Living</td><td>2021</td><td>1</td><td>626</td></tr><tr><td>Books</td><td>2021</td><td>1</td><td>61</td></tr><tr><td>Beauty & Grooming</td><td>2021</td><td>1</td><td>1201</td></tr><tr><td>Health & Sports</td><td>2021</td><td>1</t ...
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ##### Q4) Find the total spend (in percentage of total spend of categories) by customers by different age segments by different categories.

# %%
# %sql

with category_spends as (
select Category,
       sum(case when Customer_Segment = 'Young'
                then Total
           end )::decimal(10,2) as Young,
        sum(case when Customer_Segment = 'Adults'
                 then Total
            end)::decimal(10,2) as Adults,
        sum(case when Customer_Segment = 'Middle Ages'
                 then Total
            end)::decimal(10,2) as Middle_Ages,
        sum(case when Customer_Segment = 'Old'
                 then Total
            end)::decimal(10,2) as Old,
        sum(Total)::decimal(10,2) as TotalSpend
from curated.completed_customer_orders
group by 1
order by 1 
)

select Category,
       (TotalSpend/1000000)::decimal(10,2) as TotalSpend_in_million_USD,
       ((Young/TotalSpend)*100)::decimal(10,2) as Young,
       ((Adults/TotalSpend)*100)::decimal(10,2) as Adults,
       ((Middle_Ages/TotalSpend)*100)::decimal(10,2) as Middle_Ages,
       ((Old/TotalSpend)*100)::decimal(10,2) as Old
from category_spends
order by 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Category</th><th>TotalSpend_in_million_USD</th><th>Young</th><th>Adults</th><th>Middle_Ages</th><th>Old</th></tr></thead><tbody><tr><td>Appliances</td><td>14.30</td><td>4.35</td><td>27.26</td><td>33.96</td><td>34.43</td></tr><tr><td>Beauty & Grooming</td><td>1.48</td><td>4.31</td><td>26.26</td><td>33.87</td><td>35.57</td></tr><tr><td>Books</td><td>0.01</td><td>8.88</td><td>24.87</td><td>31.30</td><td>34.95</td></tr><tr><td>Computing</td><td>2.93</td><td>4.84</td><td>
td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# #### Q6) Find top 5 customers for each month
# - To calculate this, we will consider only the **completed orders**

# %%
# %sql

with top_five_month_wise as (
SELECT Year,
       MONTH(TO_DATE(Month_Year, 'MMM-yyyy')) AS Month,
       CustID,
       TotalSpend::decimal(10,2) as TotalSpend,
       rank
FROM (
    SELECT Year,
           Month_Year,
           CustID,
           SUM(Total) AS TotalSpend,
           DENSE_RANK() OVER (PARTITION BY Year,Month_Year ORDER BY SUM(Total) DESC) AS rank
    FROM curated.completed_customer_orders
    GROUP BY 1,2,3
) ranked_data
WHERE rank <= 5
ORDER BY 1, 2, TotalSpend DESC
),

customer_details as (
select CustID,
       FullName as Customer_Name,
       County,
       Gender
from curated.completed_customer_orders
group by 1,2,3,4
)

select Year,
       Month,
       top_five_month_wise.CustID,
       Customer_Name,
       County,
       Gender,
       TotalSpend,
       rank
from top_five_month_wise
inner join customer_details on customer_details.CustID = top_five_month_wise.CustID
order by 1,2, rank asc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Year</th><th>Month</th><th>CustID</th><th>Customer_Name</th><th>County</th><th>Gender</th><th>TotalSpend</th><th>rank</th></tr></thead><tbody><tr><td>2020</td><td>10</td><td>60503</td><td>Herrin, Fidela</td><td>Nemaha</td><td>F</td><td>22377.60</td><td>1</td></tr><tr><td>2020</td><td>10</td><td>61165</td><td>Wales, Humberto</td><td>Wyoming</td><td>M</td><td>19362.00</td><td>2</td></tr><tr><td>2020</td><td>10</td><td>56216</td><td>Budde, Lyndon</td><td>Claiborne</td><td>M</td><td>15929.90</td><td>3</td></tr><tr><td>2020</td><td>10</td><td>60727</td><td>Seltzer, Shaunda</td><td>Hampden</td><td>F</td><td>15065.90</td><td>4</td></tr><tr><td>2020</td><td>10</td><td>51717</td><td>Vanzandt, Yi</td><td>Chittenden</td><td>F</td><td>14947.50</td><td>5</td></tr><tr><td>2020</td><td>11</td><td>49127</td><td>Fitzsimmons, Grace</td><td>Boyle</td><td>F</td><td>25639.92</td><td>1</td></tr><tr><td>2020</td><td>11</td><td>114</td><td>Grado, Hattie</td><td>Surry</td><td>F</td><td>21260.30</td><td>2</td></tr><tr><td>2020</td><td>11</td><td>2478</td><td>Leclair, Norberto</td><td>Maricopa</td><td>M</td><td>18387.04</td><td>3</td></tr><tr><td>2020</td><td>11</td><td>44766</td><td>Ugarte, Shirl</td><td>Stark</td><td>F</td><td>15481.24</td><td>4</td></tr><tr><td>2020</td><td>11</td><td>62383</td><td>Bencomo, Zachary</td><td>Brazoria</td><td>M</td><td>13968.50</td><td>5</td></tr><tr><td>2020</td><td>12</td><td>44619</td><td>Divito, Sherlyn</td><td>Wakulla</td><td>F</td><td>129281.65</td><td>1</td></tr><tr><td>2020</td><td>12</td><td>51098</td><td>Claycomb, Shalonda</td><td>Tioga</td><td>F</td><td>96626.56</td><td>2</td></tr><tr><td>2020</td><td>12</td><td>7561</td><td>Santora, Karl</td><td>Chickasaw</td><td>M</td><td>79606.44</td><td>3</td></tr><tr><td>2020</td><td>12</td><td>37508</td><td>Francis, Rolf</td><
tr><td>180</td><td>Livengood, Mose</td><td>20</td><td>3</td><td>2493.90</td></tr><tr><td>199</td><td>Turnbull, Salome</td><td>48</td><td>1</td><td>55.00</td></tr><tr><td>210</td><td>Caviness, Cheyenne</td><td>17</td><td>7</td><td>12375.83</td></tr><tr><td>219</td><td>Bassham, Michael</td><td>5</td><td>9</td><td>6624.78</td></tr><tr><td>225</td><td>Elrod, Sofia</td><td>38</td><td>6</td><td>11030.08</td></tr><tr><td>230</td><td>Truesdell, Denyse</td><td>7</td><td>49</td><td>49597.43</td></tr><tr><td>232</td><td>Langworthy, Michiko</td><td>42</td><td>1</td><td>59.60</td></tr><tr><td>236</td><td>Emig, Foster</td><td>44</td><td>3</td><td>1966.57</td></tr><tr><td>241</td><td>Rudnick, Guadalupe</td><td>16</td><td>4</td><td>504.40</td></tr><tr><td>243</td><td>Mercer, Jesus</td><td>27</td><td>2</td><td>10 ...

# %% [markdown]
# #### Q8) Find top 10 customers based on frequency and monetary value. Sort them based on first frequency and then monetary value.

# %%
# %sql

select CustID,
       FullName as Customer_Name,
       Recency,
       Frequency,
       Monetary::decimal(10,2) as Monetary
from curated.rfm_metrics
order by Frequency desc, Monetary desc
limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustID</th><th>Customer_Name</th><th>Recency</th><th>Frequency</th><th>Monetary</th></tr></thead><tbody><tr><td>85775</td><td>Gonzalez, Joel</td><td>5</td><td>770</td><td>75702.00</td></tr><tr><td>44619</td><td>Divito, Sherlyn</td><td>7</td><td>149</td><td>248177.90</td></tr><tr><td>5769</td><td>Summerlin, Joel</td><td>21</td><td>132</td><td>125615.23</td></tr><tr><td>30465</td><td>Slattery, Tressie</td><td>21</td><td>112</td><td>137561.15</td></tr><tr><td>800</td><td>Jesse, Alfonso</td><td>7</td><td>105</td><td>50630.12</td></tr><tr><td>32</td><td>Horne, Reginald</td><td>7</td><td>97</td><td>47835.19</td></tr><tr><td>56</td><td>Oswald, Rene</td><td>13</td><td>92</td><td>71619.25</td></tr><tr><td>48199</td><td>Klar, Irving</td><td>6</td><td>90</td><td>79178.02</td></tr><tr><td>14625</td><td>Pitre, Shayla</td><td>6</td><td>87</td><td>85478.63</td></tr><tr><td>44445</td><td>Flanigan, Yong</td><td>21</td><td>87</td><td>72097.83</td></tr></tbody></table></div>

# %% [markdown]
# #### Q9) Additional Insights

# %% [markdown]
# #### a) Find the number of orders purchased, grouped by the State.

# %%
# %sql

select State,
       Count(distinct OrderID) as unique_orders
from curated.completed_customer_orders
group by 1
order by 2 desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>State</th><th>unique_orders</th></tr></thead><tbody><tr><td>CA</td><td>6215</td></tr><tr><td>TX</td><td>5740</td></tr><tr><td>NY</td><td>4998</td></tr><tr><td>PA</td><td>4738</td></tr><tr><td>IL</td><td>3987</td></tr><tr><td>FL</td><td>3507</td></tr><tr><td>OH</td><td>3260</td></tr><tr><td>MO</td><td>2884</td></tr><tr><td>VA</td><td>2852</td></tr><tr><td>IA</td><td>2566</td></tr><tr><td>MI</td><td>2482</td></tr><tr><td>NC</td><td>2461</td></tr><tr><td>KY</td><td>2365</td></tr><tr><td>M
td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# #### c) Payment preferences of customer segments

# %%
# %sql

-- First view the different payment methods given to us
select *
from curated.completed_customer_orders
limit 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustID</th><th>OrderID</th><th>Order_Date</th><th>Status</th><th>ItemID</th><th>Quantity_Ordered</th><th>Price</th><th>Value</th><th>Discount_Amount</th><th>Total</th><th>Category</th><th>Payment_Method</th><th>Month_Year</th><th>Year</th><th>City</th><th>County</th><th>CustomerSince</th><th>Email</th><th>Gender</th><th>PlaceName</th><th>Region</th><th>State</th><th>Zip</th><th>Age</th><th>FullName</th><th>Customer_Segment</th></tr></thead><tbody><tr><td>82529</td><td>100433524</td><td>2021-01-08</td><td>complete</td><td>709387</td><td>2</td><td>109.9</td><td>109.9</td><td>0.0</td><td>109.9</td><td>Beauty & Grooming</td><td>cod</td><td>Jan-2021</td><td>2021</td><td>Malta</td><td>DeKalb</td><td>1995-10-19</td><td>annie.showman@hotmail.com</td><td>F</td><td>Malta</td><td>Midwest</td><td>IL</td><td>60150</td><td>30</td><td>Showman, Annie</td><td>Adults</td></tr></tbody></table></div>

# %% [markdown]
# Let us categorise them into four categories based on the following logic:
#
# Digital Wallets:
# - jazzwallet
# - Easypay_MA
# - Easypay
# - apg
# - Payaxis
# - mcblite
#
# Voucher/Credit:
# - easypay_voucher
# - customercredit
# - jazzvoucher
#
# Cash Handling/Delivery:
# - cashatdoorstep
# - cod
#
# Bank Transactions:
# - bankalfalah

# %%
# %sql


with payment_methods as (
select Customer_Segment,
       count(distinct case when Payment_Method in ('jazzwallet','Easypay_MA','Easypay','apg','Payaxis','mcblite')
                           then OrderID
                      end) as Digital_Wallet,
      count(distinct case when Payment_Method in ('easypay_voucher','customercredit','jazzvoucher')
                          then OrderID
                      end) as Voucher,
      count(distinct case when Payment_Method in ('cod','cashatdoorstep')
                          then OrderID
                      end) as CoD,
      count(distinct case when Payment_Method ilike '%bank%'
                          then OrderID
                      end) as Bank,
      count(distinct OrderID) as TotalOrders
from curated.completed_customer_orders
group by 1
order by 1
)

select  Customer_Segment,
       ((Digital_Wallet/TotalOrders)*100)::decimal(10,2) as DigitalWallet,
       ((Voucher/TotalOrders)*100)::decimal(10,2) as Voucher,
       ((CoD/TotalOrders)*100)::decimal(10,2) as CoD,
       ((Bank/TotalOrders)*100)::decimal(10,2) as Bank
from payment_methods
order by 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Customer_Segment</th><th>DigitalWallet</th><th>Voucher</th><th>CoD</th><th>Bank</th></tr></thead><tbody><tr><td>Adults</td><td>32.76</td><td>21.76</td><td>41.39</td><td>4.10</td></tr><tr><td>Middle Ages</td><td>32.40</td><td>21.49</td><td>41.82</td><td>4.29</td></tr><tr><td>Old</td><td>32.99</td><td>21.65</td><td>41.29</td><td>4.06</td></tr><tr><td>Young</td><td>30.46</td><td>24.23</td><td>41.64</td><td>3.67</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.
